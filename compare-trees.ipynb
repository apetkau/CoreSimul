# %%
library(ape)
library(phytools)
library(phangorn)
library(repr)

t_orig <- read.tree(file="example.tree")
t_new <- read.tree(file="test/core.fa.treefile")
t_renamed <- read.tree(file="test/renamed.tree")

t_orig <- root(t_orig, "B16", resolve.root=TRUE)
t_new <- root(t_new, "BOZO0034", resolve.root=TRUE)
t_renamed <- root(t_renamed, "BOZO0034", resolve.root=TRUE)

comparePhylo(t_renamed, t_new, plot=TRUE)
# Out:
# Loading required package: maps
# => Comparing t_renamed with t_new.
# Both trees have the same number of tips: 34.
# Both trees have the same tip labels.
# Both trees have the same number of nodes: 33.
# Both trees are rooted.
# Both trees are not ultrametric.
# 13 clades in t_renamed not in t_new.
# 13 clades in t_new not in t_renamed.
# Plot with title "t_new"

# %%
treedist(t_renamed, t_new, check.labels = TRUE)
# Out:
#      symmetric.difference   branch.score.difference           path.difference
#                26.0000000                 0.1253517                54.9636243
# quadratic.path.difference
#                 1.9759804

# %%
options(repr.plot.width=10, repr.plot.height=8)

plot(cophylo(t_renamed, t_new, rotate=TRUE))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title

# %%
tip_association <- read.table("test/names.txt")
tip_association["tmp"] <- tip_association[,1]
tip_association["V1"] <- tip_association["V2"]
tip_association["V2"] <- tip_association["tmp"]
tip_association["tmp"] <- NULL
tip_association
# Out:
#    V1       V2
# 1  Samanta  BOZO0001
# 2  Vincent  BOZO0002
# 3  Jason    BOZO0003
# 4  Pedro    BOZO0004
# 5  B24      BOZO0005
# 6  B29      BOZO0006
# 7  coucou   BOZO0007
# 8  B15      BOZO0008
# 9  B19      BOZO0009
# 10 hello    BOZO0010
# 11 B2       BOZO0011
# 12 B25      BOZO0012
# 13 B32      BOZO0013
# 14 B37      BOZO0014
# 15 B13      BOZO0015
# 16 B3       BOZO0016
# 17 B5       BOZO0017
# 18 B4       BOZO0018
# 19 Michel56 BOZO0019
# 20 B18      BOZO0020
# 21 B35      BOZO0021
# 22 B7       BOZO0022
# 23 B26      BOZO0023
# 24 B8       BOZO0024
# 25 B11      BOZO0025
# 26 B14      BOZO0026
# 27 B10      BOZO0027
# 28 B42      BOZO0028
# 29 B33      BOZO0029
# 30 B21      BOZO0030
# 31 B1       BOZO0031
# 32 B12      BOZO0032
# 33 B17      BOZO0033
# 34 B16      BOZO0034

# %%
plot(cophylo(t_orig, t_renamed, rotate=TRUE, assoc=tip_association))
# Out:
# Rotating nodes to optimize matching...
# Done.
# plot without title
